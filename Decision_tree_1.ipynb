# %%
import pandas as pd
pd.options.display.max_columns=1000
pd.options.display.width=200
pd.options.display.min_rows=60
import numpy as np

from sklearn.tree import DecisionTreeClassifier 
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn import preprocessing
from sklearn.tree import export_graphviz
import pydotplus

from datetime import datetime

# %%
def compare_dicts(a,b,ignore=['test_score','train_score','tn','fn','tp','fp','f1_score','precision','recall']):
    a = dict(a)
    b = dict(b)
    for k in ignore:
        a.pop(k,None)
        b.pop(k,None)
        
    return tuple(a.items()) == tuple(b.items())

# %%
hyperparam_table = []

# %%
filename = 'data_cleanednlp2.csv'
df =  pd.read_csv(filename,index_col=0)

#select only columns with int or float data types
df = df.select_dtypes(['number'])
#drop any columns with null values
df.dropna(axis=1,inplace=True)
#remove the class series
var_class = df.pop('CLASS')

x_train,x_test,y_train,y_test = train_test_split(df,var_class,test_size=0.05,random_state=0)
x_train.to_csv(filename[:-4]+'_xtrain.csv',index=False)
x_test.to_csv(filename[:-4]+'_xtest.csv',index=False)
y_train.to_csv(filename[:-4]+'_ytrain.csv',index=False,header=False)
y_test.to_csv(filename[:-4]+'_ytest.csv',index=False,header=False)

exists = any([compare_dicts(a,b={'test_size': 0.05, 
                                'random_state': 0, 
                                'data_size': str(df.shape),
                                'scaling':'no_scaling',
                                'filename': filename,
                                'model': 'sklearn.DecisionTreeClassifier'
                                }) 
              for a in hyperparam_table])

clf = DecisionTreeClassifier()

if not exists:
    hyperparam_table += [{'test_size': 0.05, 
                          'random_state': 0, 
                          'data_size': str(df.shape),
                          'scaling':'no_scaling',
                          'filename': filename,
                          'model': 'sklearn.DecisionTreeClassifier'
                         }]
        
    clf = clf.fit(x_train,y_train)
    
    predictions_test = clf.predict(X=x_test)
    predictions_train = clf.predict(X=x_train)
    
    score = clf.score(x_test,y_test)
    hyperparam_table[-1]['test_score'] = score
    
    training_score = clf.score(x_train,y_train)
    hyperparam_table[-1]['train_score'] = training_score
    
    tn, fp, fn, tp = confusion_matrix(y_test,predictions_test).ravel()
    hyperparam_table[-1]['tn'] = tn
    hyperparam_table[-1]['fp'] = fp
    hyperparam_table[-1]['fn'] = fn
    hyperparam_table[-1]['tp'] = tp
    
    f1 = f1_score(y_test,predictions_test)
    hyperparam_table[-1]['f1_score'] = f1
    precision = precision_score(y_test,predictions_test)
    hyperparam_table[-1]['precision'] = precision
    recall = recall_score(y_test,predictions_test)
    hyperparam_table[-1]['recall'] = recall
# Out:
# /home/gksullan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_hyp = pd.DataFrame(hyperparam_table)
df_hyp.head()
# Out:
#    test_size  random_state    data_size     scaling              filename                           model  test_score  train_score    tn   fp   fn   tp  f1_score  precision    recall
# 0       0.05             0  (65188, 55)  no_scaling  data_cleanednlp2.csv  sklearn.DecisionTreeClassifier    0.694479     0.999855  1931  491  505  333  0.400722   0.404126  0.397375

# %%
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1672             else:
# -> 1673                 loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1674
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    2876             return loc + 1, self.match
# -> 2877         raise ParseException(instring, loc, self.errmsg, self)
#    2878
#
# ParseException: Expected "#", found 'X'  (at char 2113984), (line:36161, col:15)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-61b2087b5ffd> in <module>
#       3                 filled=True, rounded=True,
#       4                 special_characters=True)
# ----> 5 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#       6 Image(graph.create_png())
#
# ~/anaconda3/lib/python3.7/site-packages/pydotplus/graphviz.py in graph_from_dot_data(data)
#     300     """
#     301
# --> 302     return parser.parse_dot_data(data)
#     303
#     304
#
# ~/anaconda3/lib/python3.7/site-packages/pydotplus/parser.py in parse_dot_data(data)
#     556             graphparser.parseWithTabs()
#     557
# --> 558         tokens = graphparser.parseString(data)
#     559
#     560         if len(tokens) == 1:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1927             instring = instring.expandtabs()
#    1928         try:
# -> 1929             loc, tokens = self._parse(instring, 0)
#    1930             if parseAll:
#    1931                 loc = self.preParse(instring, loc)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4663         if check_ender:
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#    4667             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4815     def parseImpl(self, instring, loc, doActions=True):
#    4816         try:
# -> 4817             loc, tokens = self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4818         except (ParseException, IndexError):
#    4819             if self.defaultValue is not self.__optionalNotMatched:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4673                 else:
#    4674                     preloc = loc
# -> 4675                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4676                 if tmptokens or tmptokens.haskeys():
#    4677                     tokens += tmptokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4018         # pass False as last arg to _parse for first element, since we already
#    4019         # pre-parsed the string as part of our And pre-parsing
# -> 4020         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4021         errorStop = False
#    4022         for e in self.exprs[1:]:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4815     def parseImpl(self, instring, loc, doActions=True):
#    4816         try:
# -> 4817             loc, tokens = self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4818         except (ParseException, IndexError):
#    4819             if self.defaultValue is not self.__optionalNotMatched:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4663         if check_ender:
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#    4667             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4815     def parseImpl(self, instring, loc, doActions=True):
#    4816         try:
# -> 4817             loc, tokens = self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4818         except (ParseException, IndexError):
#    4819             if self.defaultValue is not self.__optionalNotMatched:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4663         if check_ender:
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#    4667             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4815     def parseImpl(self, instring, loc, doActions=True):
#    4816         try:
# -> 4817             loc, tokens = self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4818         except (ParseException, IndexError):
#    4819             if self.defaultValue is not self.__optionalNotMatched:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4747     def parseImpl(self, instring, loc, doActions=True):
#    4748         try:
# -> 4749             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4750         except (ParseException, IndexError):
#    4751             return loc, []
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4663         if check_ender:
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#    4667             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1661         else:
#    1662             if callPreParse and self.callPreparse:
# -> 1663                 preloc = self.preParse(instring, loc)
#    1664             else:
#    1665                 preloc = loc
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in preParse(self, instring, loc)
#    1614     def preParse(self, instring, loc):
#    1615         if self.ignoreExprs:
# -> 1616             loc = self._skipIgnorables(instring, loc)
#    1617
#    1618         if self.skipWhitespace:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _skipIgnorables(self, instring, loc)
#    1606                 try:
#    1607                     while 1:
# -> 1608                         loc, dummy = e._parse(instring, loc)
#    1609                         exprsFound = True
#    1610                 except ParseException:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4018         # pass False as last arg to _parse for first element, since we already
#    4019         # pre-parsed the string as part of our And pre-parsing
# -> 4020         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4021         errorStop = False
#    4022         for e in self.exprs[1:]:
#
# ~/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1840                 if isinstance(value, Exception):
#    1841                     raise value
# -> 1842                 return value[0], value[1].copy()
#    1843
#    1844     _parse = _parseNoCache
#
# KeyboardInterrupt:

# %%
filename = 'clinvar_conflicting.csv'
df =  pd.read_csv(filename)

#select only columns with int or float data types
df = df.select_dtypes(['number'])
#drop any columns with null values
df.dropna(axis=1,inplace=True)
#remove the class series
var_class = df.pop('CLASS')

x_train,x_test,y_train,y_test = train_test_split(df,var_class,test_size=0.05,random_state=0)
x_train.to_csv(filename[:-4]+'_xtrain.csv',index=False)
x_test.to_csv(filename[:-4]+'_xtest.csv',index=False)
y_train.to_csv(filename[:-4]+'_ytrain.csv',index=False,header=False)
y_test.to_csv(filename[:-4]+'_ytest.csv',index=False,header=False)

exists = any([compare_dicts(a,b={'test_size': 0.05, 
                                'random_state': 0, 
                                'data_size': str(df.shape),
                                'scaling':'no_scaling',
                                'filename': filename,
                                'model': 'sklearn.DecisionTreeClassifier'
                                }) 
              for a in hyperparam_table])

clf = DecisionTreeClassifier()

if not exists:
    hyperparam_table += [{'test_size': 0.05, 
                          'random_state': 0, 
                          'data_size': str(df.shape),
                          'scaling':'no_scaling',
                          'filename': filename,
                          'model': 'sklearn.DecisionTreeClassifier'
                         }]
        
    clf = clf.fit(x_train,y_train)
    
    predictions_test = clf.predict(X=x_test)
    predictions_train = clf.predict(X=x_train)
    
    score = clf.score(x_test,y_test)
    hyperparam_table[-1]['test_score'] = score
    
    training_score = clf.score(x_train,y_train)
    hyperparam_table[-1]['train_score'] = training_score
    
    tn, fp, fn, tp = confusion_matrix(y_test,predictions_test).ravel()
    hyperparam_table[-1]['tn'] = tn
    hyperparam_table[-1]['fp'] = fp
    hyperparam_table[-1]['fn'] = fn
    hyperparam_table[-1]['tp'] = tp
    
    f1 = f1_score(y_test,predictions_test)
    hyperparam_table[-1]['f1_score'] = f1
    precision = precision_score(y_test,predictions_test)
    hyperparam_table[-1]['precision'] = precision
    recall = recall_score(y_test,predictions_test)
    hyperparam_table[-1]['recall'] = recall
# Out:
# /home/gksullan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,38,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_hyp = pd.DataFrame(hyperparam_table)
df_hyp.head()
# Out:
#    test_size  random_state    data_size     scaling                 filename                           model  test_score  train_score    tn   fp   fn   tp  f1_score  precision    recall
# 0       0.05             0  (65188, 55)  no_scaling     data_cleanednlp2.csv  sklearn.DecisionTreeClassifier    0.694479     0.999855  1931  491  505  333  0.400722   0.404126  0.397375
# 1       0.05             0   (65188, 4)  no_scaling  clinvar_conflicting.csv  sklearn.DecisionTreeClassifier    0.698466     0.991862  1940  482  501  337  0.406759   0.411477  0.402148

# %%
clf.decision_path(x_train)
# Out:
# <61928x32663 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1460224 stored elements in Compressed Sparse Row format>
