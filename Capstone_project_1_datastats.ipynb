# %%
import pandas as pd

# %%
#Medicare payment data
df = pd.read_csv('Payment_and_value_of_care_-_Hospital.csv')

# %%
df.head()
# Out:
#    Facility ID                  Facility Name                Address  \
# 0       351331   TOWNER COUNTY MEDICAL CENTER              HWY 281 N
# 1       521356  BELLIN HEALTH OCONTO HOSPITAL        820 ARBUTUS AVE
# 2       390025            KENSINGTON HOSPITAL   136 W DIAMOND STREET
# 3       400128   HOSPITAL PAVIA HATO REY, INC  AVE PONCE DE LEON 435
# 4       141338              MEMORIAL HOSPITAL          1900 STATE ST
#
#            City State  ZIP Code   County name    Phone number  \
# 0         CANDO    ND     58324        TOWNER  (701) 968-4411
# 1        OCONTO    WI     54153        OCONTO  (920) 835-1101
# 2  PHILADELPHIA    PA     19122  PHILADELPHIA  (215) 426-8100
# 3      HATO REY    PR       919      SAN JUAN  (787) 754-0909
# 4       CHESTER    IL     62233      RANDOLPH  (618) 826-4581
#
#          Measure ID                               Measure Name  ...  \
# 0  PAYM_90_HIP_KNEE  Payment for hip/knee replacement patients  ...
# ...

# %%
df.corr()
# Out:
#                         Facility ID  ZIP Code  Payment footnote  \
# Facility ID                1.000000 -0.112897          0.084734
# ZIP Code                  -0.112897  1.000000         -0.024380
# Payment footnote           0.084734 -0.024380          1.000000
# Value of care footnote     0.040904 -0.057981          0.672741
#
#                         Value of care footnote
# Facility ID                           0.040904
# ZIP Code                             -0.057981
# Payment footnote                      0.672741
# Value of care footnote                1.000000

# %%
df.describe()
# Out:
#          Facility ID      ZIP Code  Payment footnote  Value of care footnote
# count   19028.000000  19028.000000       6669.000000             6676.000000
# mean   267552.614042  54056.017658          3.829210               13.241462
# std    156904.047378  26936.416366          4.743487                2.114433
# min     10001.000000    603.000000          1.000000                5.000000
# 25%    140174.000000  33016.000000          1.000000               13.000000
# 50%    260024.000000  55422.000000          1.000000               13.000000
# 75%    390201.000000  76104.000000          5.000000               13.000000
# max    670128.000000  99929.000000         23.000000               23.000000

# %%
#Medicare complication rate for hip and knee replacement
#https://catalog.data.gov/dataset/comprehensive-care-for-joint-replacement-model-provider-data/resource/d9f25a0b-0512-4adc-8b18-6be25720cf0d
df2 = pd.read_csv('Comprehensive_Care_For_Joint_Replacement_Model_-_Provider_Data.csv')

# %%
df2.head()
# Out:
#    FACILITY ID                         FACILITY NAME      MSA  \
# 0      10001.0      SOUTHEAST ALABAMA MEDICAL CENTER  20020.0
# 1      10023.0          BAPTIST MEDICAL CENTER SOUTH  33860.0
# 2      10055.0                      FLOWERS HOSPITAL  20020.0
# 3      10092.0         D C H REGIONAL MEDICAL CENTER  46220.0
# 4      40026.0  CHI ST. VINCENT HOSPITAL HOT SPRINGS  26300.0
#
#          MSA TITLE  HCAHPS HLMR HCAHPS HLMR PERCENTILE HCAHPS START DATE  \
# 0       Dothan, AL        81.75                    10%        07/01/2017
# 1   Montgomery, AL        84.13                    30%        07/01/2017
# 2       Dothan, AL        86.50                    60%        07/01/2017
# 3   Tuscaloosa, AL        83.56                    20%        07/01/2017
# 4  Hot Springs, AR        84.44                    30%        07/01/2017
#
#   HCAHPS END DATE HCAHPS FOOTNOTE  COMP-HIP-KNEE COMP-HIP-KNEE PERCENTILE  \
# 0      06/30/2018             NaN        3.18631                      20%
# ...

# %%
df2.describe()
# Out:
#          FACILITY ID           MSA  HCAHPS HLMR  COMP-HIP-KNEE  COMP FOOTNOTE
# count     489.000000    489.000000   473.000000     423.000000      66.000000
# mean   245295.588957  32865.807771    84.851332       2.529265       1.484848
# std    156413.569967   8240.755216     3.315915       0.504873       1.571304
# min     10001.000000  10420.000000    66.880000       1.428420       1.000000
# 25%    100071.000000  31080.000000    83.000000       2.173300       1.000000
# 50%    310024.000000  35380.000000    85.250000       2.490390       1.000000
# 75%    360351.000000  36420.000000    86.940000       2.823770       1.000000
# max    670080.000000  48620.000000    93.810000       4.619700       7.000000

# %%
df2.corr()
# Out:
#                FACILITY ID       MSA  HCAHPS HLMR  COMP-HIP-KNEE  \
# FACILITY ID       1.000000 -0.132646     0.238865       0.005402
# MSA              -0.132646  1.000000    -0.097801       0.011379
# HCAHPS HLMR       0.238865 -0.097801     1.000000      -0.133526
# COMP-HIP-KNEE     0.005402  0.011379    -0.133526       1.000000
# COMP FOOTNOTE     0.011322 -0.266630     0.095897            NaN
#
#                COMP FOOTNOTE
# FACILITY ID         0.011322
# MSA                -0.266630
# HCAHPS HLMR         0.095897
# COMP-HIP-KNEE            NaN
# COMP FOOTNOTE       1.000000

# %%
df2.shape
# Out:
# (490, 18)

# %%
df.shape
# Out:
# (19028, 23)

# %%
#UCI heart dataset 
df3 = pd.read_csv('heart.csv')

# %%
df3.shape
df3.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df3.shape
# Out:
# (303, 14)

# %%
#http://archive.ics.uci.edu/ml/datasets/Breast+Tissue
df4 = pd.read_csv('BreastTissue.csv')

# %%
df4.head()
# Out:
#    Case # Class          I0     PA500       HFS          DA          Area  \
# 0       1   car  524.794072  0.187448  0.032114  228.800228   6843.598481
# 1       2   car  330.000000  0.226893  0.265290  121.154201   3163.239472
# 2       3   car  551.879287  0.232478  0.063530  264.804935  11888.391827
# 3       4   car  380.000000  0.240855  0.286234  137.640111   5402.171180
# 4       5   car  362.831266  0.200713  0.244346  124.912559   3290.462446
#
#         A/DA     Max IP          DR           P
# 0  29.910803  60.204880  220.737212  556.828334
# 1  26.109202  69.717361   99.084964  400.225776
# 2  44.894903  77.793297  253.785300  656.769449
# 3  39.248524  88.758446  105.198568  493.701814
# 4  26.342127  69.389389  103.866552  424.796503

# %%
df4.corr()
# Out:
#           Case #        I0     PA500       HFS        DA      Area      A/DA  \
# Case #  1.000000  0.769624 -0.606826 -0.134830  0.548759  0.354170  0.264588
# I0      0.769624  1.000000 -0.393647  0.028455  0.819606  0.560098  0.612070
# PA500  -0.606826 -0.393647  1.000000  0.509019 -0.089817  0.083547  0.229837
# HFS    -0.134830  0.028455  0.509019  1.000000  0.106977  0.206059  0.356028
# DA      0.548759  0.819606 -0.089817  0.106977  1.000000  0.731132  0.648334
# Area    0.354170  0.560098  0.083547  0.206059  0.731132  1.000000  0.830172
# A/DA    0.264588  0.612070  0.229837  0.356028  0.648334  0.830172  1.000000
# Max IP  0.535138  0.823668 -0.050401  0.370827  0.753227  0.735258  0.812815
# DR      0.486888  0.733252 -0.077054  0.011592  0.974202  0.675810  0.540695
# P       0.735818  0.988697 -0.345715  0.102362  0.774028  0.574073  0.679363
#
#           Max IP        DR         P
# Case #  0.535138  0.486888  0.735818
# I0      0.823668  0.733252  0.988697
# ...

# %%
df4.describe()
# Out:
#            Case #           I0       PA500         HFS           DA  \
# count  106.000000   106.000000  106.000000  106.000000   106.000000
# mean    53.500000   784.251618    0.120133    0.114691   190.568642
# std     30.743563   753.950075    0.068596    0.101347   190.801448
# min      1.000000   103.000000    0.012392   -0.066323    19.647670
# 25%     27.250000   250.000000    0.067413    0.043982    53.845470
# 50%     53.500000   384.936489    0.105418    0.086568   120.777303
# 75%     79.750000  1487.989626    0.169602    0.166504   255.334809
# max    106.000000  2800.000000    0.358316    0.467748  1063.441427
#
#                 Area        A/DA      Max IP          DR            P
# count     106.000000  106.000000  106.000000  106.000000   106.000000
# mean     7335.155162   23.473784   75.381258  166.710575   810.638127
# std     18580.314213   23.354672   81.345838  181.309580   763.019135
# min        70.426239    1.595742    7.968783   -9.257696   124.978561
# ...

# %%
#1 year survival or death rate after thoracic surgery -lung carcincoma
#http://archive.ics.uci.edu/ml/datasets/Thoracic+Surgery+Data
df5 = pd.read_csv('ThoraricSurgery.csv')

# %%
df5.head()
# Out:
#     DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19 PRE25  \
# 0  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F     F
# 1  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F     F
# 2  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F     F
# 3  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F     F
# 4  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F     F
#
#   PRE30 PRE32  Age Death
# 0     T     F   60     F
# 1     T     F   51     F
# 2     T     F   59     F
# 3     F     F   54     F
# 4     T     F   73     T

# %%
df5.shape
# Out:
# (470, 17)

# %%
#conflicting clinical genomic classification
#https://www.kaggle.com/kevinarvai/clinvar-conflicting
df6 = pd.read_csv('clinvar_conflicting.csv', dtype=object)

# %%
df6.shape
# Out:
# (65188, 46)

# %%
df6.head()
# Out:
#   CHROM     POS REF ALT  AF_ESP  AF_EXAC  AF_TGP  \
# 0     1  955563   G   C       0        0       0
# 1     1  955597   G   T       0  0.42418  0.2826
# 2     1  955619   G   C       0  0.03475  0.0088
# 3     1  957640   C   T  0.0318  0.02016  0.0328
# 4     1  976059   C   T       0  0.00022  0.0010
#
#                                       CLNDISDB CLNDISDBINCL  \
# 0  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 1                              MedGen:CN169374          NaN
# 2  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 3  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 4                              MedGen:CN169374          NaN
#
#                                               CLNDN  ... SIFT PolyPhen  \
# 0  Myasthenic_syndrome,_congenital,_8|not_specified  ...  NaN      NaN
# 1                                     not_specified  ...  NaN      NaN
# 2  Myasthenic_syndrome,_congenital,_8|not_specified  ...  NaN      NaN
# ...

# %%
df6.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df6.describe()
# Out:
#         CHROM       POS    REF    ALT AF_ESP AF_EXAC AF_TGP         CLNDISDB  \
# count   65188     65188  65188  65188  65188   65188  65188            65188
# unique     24     63115    866    458   2842    6667   2088             9234
# top         2  89876827      C      T      0       0      0  MedGen:CN169374
# freq     8645        11  21798  20409  35781   24047  37951             5344
#
#        CLNDISDBINCL          CLNDN  ...         SIFT PolyPhen     MOTIF_NAME  \
# count            76          65188  ...        24836    24796              2
# unique           48           9260  ...            4        4              2
# top               .  not_specified  ...  deleterious   benign  Egr1:MA0341.1
# freq              7           5344  ...        11500    13329              1
#
#        MOTIF_POS HIGH_INF_POS MOTIF_SCORE_CHANGE LoFtool CADD_PHRED  CADD_RAW  \
# count          2            2                  2   60975      64096     64096
# ...
