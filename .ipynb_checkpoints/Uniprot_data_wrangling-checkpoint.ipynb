# %%
import pandas as pd

# %%
uniprot_df = pd.read_csv('uniprot_data.csv')

# %%
uniprot_df.head()
# Out:
#   yourlist:M201912106746803381A1F0E0DB47453E0216320D314B872       Entry  \
# 0                                               AGRN         A0A087X208
# 1                                               AGRN         A0A494C0G5
# 2                                               AGRN         A0A494C1I6
# 3                                               AGRN             O00468
# 4                                               AGRN             Q15952
#
#          Entry name      Status  \
# 0  A0A087X208_HUMAN  unreviewed
# 1  A0A494C0G5_HUMAN  unreviewed
# 2  A0A494C1I6_HUMAN  unreviewed
# 3       AGRIN_HUMAN    reviewed
# 4      Q15952_HUMAN  unreviewed
#
#                                        Protein names  Gene names  \
# 0                                              Agrin        AGRN
# 1                                              Agrin        AGRN
# 2                                              Agrin        AGRN
# 3  Agrin [Cleaved into: Agrin N-terminal 110 kDa ...  AGRN AGRIN
# 4                                   Agrin (Fragment)        AGRN
#
#                Organism  Length
# 0  Homo sapiens (Human)    1930
# 1  Homo sapiens (Human)    1940
# 2  Homo sapiens (Human)    1963
# 3  Homo sapiens (Human)    2068
# 4  Homo sapiens (Human)      62

# %%
#clean the uniprot data by only taking entries where the Status has been reviewed - most canonical sequence
#Take only the length of the protein and rename the columns
#Group by the symbol and take the average length 
clean_uniprot = uniprot_df[uniprot_df['Status'] == 'reviewed']
length_df = clean_uniprot[['yourlist:M201912106746803381A1F0E0DB47453E0216320D314B872','Length']]
length_df.columns = ['SYMBOL','Length']
length_df = length_df.groupby('SYMBOL').mean()
length_df.reset_index(inplace=True)

# %%
length_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2321 entries, 0 to 2320
# Data columns (total 2 columns):
# SYMBOL    2321 non-null object
# Length    2321 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 36.4+ KB

# %%
#Read in cleaned data set 
df = pd.read_csv('data_cleaned1.csv')
# Out:
# /home/gksullan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#       POS REF ALT  AF_ESP  AF_EXAC  AF_TGP  \
# 0  955563   G   C  0.0000  0.00000  0.0000
# 1  955597   G   T  0.0000  0.42418  0.2826
# 2  955619   G   C  0.0000  0.03475  0.0088
# 3  957640   C   T  0.0318  0.02016  0.0328
# 4  976059   C   T  0.0000  0.00022  0.0010
#
#                                       CLNDISDB CLNDISDBINCL  \
# 0  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 1                              MedGen:CN169374          NaN
# 2  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 3  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 4                              MedGen:CN169374          NaN
#
#                                               CLNDN CLNDNINCL  ... INT EX  \
# 0  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...   0  1
# 1                                     not_specified       NaN  ...   0  1
# 2  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...   0  1
# 3  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...   0  1
# 4                                     not_specified       NaN  ...   0  1
#
#   SIFT_deleterious SIFT_deleterious_low_confidence  SIFT_tolerated  \
# 0                0                               0               0
# 1                0                               0               0
# 2                0                               0               0
# 3                0                               0               0
# 4                0                               0               0
#
#    SIFT_tolerated_low_confidence  SIFT_unknown BIOTYPE_misc_RNA  \
# 0                              0             1                0
# 1                              0             1                0
# 2                              0             1                0
# 3                              0             1                0
# 4                              0             1                0
#
#   BIOTYPE_protein_coding BIOTYPE_unknown
# 0                      1               0
# 1                      1               0
# 2                      1               0
# 3                      1               0
# 4                      1               0
#
# [5 rows x 84 columns]

# %%
#Join the original data frame with the uniprot length data using merge on "SYMBOL"
new_df = df.merge(length_df, on='SYMBOL', how='left')

# %%
new_df.head()
# Out:
#       POS REF ALT  AF_ESP  AF_EXAC  AF_TGP  \
# 0  955563   G   C  0.0000  0.00000  0.0000
# 1  955597   G   T  0.0000  0.42418  0.2826
# 2  955619   G   C  0.0000  0.03475  0.0088
# 3  957640   C   T  0.0318  0.02016  0.0328
# 4  976059   C   T  0.0000  0.00022  0.0010
#
#                                       CLNDISDB CLNDISDBINCL  \
# 0  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 1                              MedGen:CN169374          NaN
# 2  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 3  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 4                              MedGen:CN169374          NaN
#
#                                               CLNDN CLNDNINCL  ... EX  \
# 0  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...  1
# 1                                     not_specified       NaN  ...  1
# 2  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...  1
# 3  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...  1
# 4                                     not_specified       NaN  ...  1
#
#   SIFT_deleterious SIFT_deleterious_low_confidence SIFT_tolerated  \
# 0                0                               0              0
# 1                0                               0              0
# 2                0                               0              0
# 3                0                               0              0
# 4                0                               0              0
#
#    SIFT_tolerated_low_confidence  SIFT_unknown  BIOTYPE_misc_RNA  \
# 0                              0             1                 0
# 1                              0             1                 0
# 2                              0             1                 0
# 3                              0             1                 0
# 4                              0             1                 0
#
#   BIOTYPE_protein_coding BIOTYPE_unknown  Length
# 0                      1               0  2068.0
# 1                      1               0  2068.0
# 2                      1               0  2068.0
# 3                      1               0  2068.0
# 4                      1               0  2068.0
#
# [5 rows x 85 columns]

# %%
#make sure all of the entries in "Protein_position" column are numeric
#Fill in missing values in the protein position and length columns as the mean of those columns
#Calculate Relative location = Protein position/Length
new_df.Protein_position = pd.to_numeric(new_df.Protein_position,errors='coerce')

new_df['Relative_Location'] = new_df.Protein_position/new_df.Length

# %%
new_df.Relative_Location.fillna(0, inplace=True)
new_df.head()
# Out:
#       POS REF ALT  AF_ESP  AF_EXAC  AF_TGP  \
# 0  955563   G   C  0.0000  0.00000  0.0000
# 1  955597   G   T  0.0000  0.42418  0.2826
# 2  955619   G   C  0.0000  0.03475  0.0088
# 3  957640   C   T  0.0318  0.02016  0.0328
# 4  976059   C   T  0.0000  0.00022  0.0010
#
#                                       CLNDISDB CLNDISDBINCL  \
# 0  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 1                              MedGen:CN169374          NaN
# 2  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 3  MedGen:C3808739,OMIM:615120|MedGen:CN169374          NaN
# 4                              MedGen:CN169374          NaN
#
#                                               CLNDN CLNDNINCL  ...  \
# 0  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...
# 1                                     not_specified       NaN  ...
# 2  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...
# 3  Myasthenic_syndrome,_congenital,_8|not_specified       NaN  ...
# 4                                     not_specified       NaN  ...
#
#   SIFT_deleterious SIFT_deleterious_low_confidence SIFT_tolerated  \
# 0                0                               0              0
# 1                0                               0              0
# 2                0                               0              0
# 3                0                               0              0
# 4                0                               0              0
#
#   SIFT_tolerated_low_confidence  SIFT_unknown  BIOTYPE_misc_RNA  \
# 0                             0             1                 0
# 1                             0             1                 0
# 2                             0             1                 0
# 3                             0             1                 0
# 4                             0             1                 0
#
#    BIOTYPE_protein_coding BIOTYPE_unknown  Length Relative_Location
# 0                       1               0  2068.0          0.001934
# 1                       1               0  2068.0          0.007253
# 2                       1               0  2068.0          0.011122
# 3                       1               0  2068.0          0.042070
# 4                       1               0  2068.0          0.085106
#
# [5 rows x 86 columns]

# %%
#save new dataframe with joined data to a new csv file
new_df.to_csv('data_cleaned4.csv',index=False)
